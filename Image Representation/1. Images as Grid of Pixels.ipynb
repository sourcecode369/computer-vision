# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
# %matplotlib qt

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1404-441A
#
#  Directory of C:\Users\User\Desktop\deep learning nanodegree\Computer_Vision\Image Representation
#
# 08/26/2019  12:25 AM    <DIR>          .
# 08/26/2019  12:25 AM    <DIR>          ..
# 08/26/2019  12:25 AM    <DIR>          .ipynb_checkpoints
# 08/26/2019  12:24 AM           608,347 1. Images as Grid of Pixels.ipynb
# 08/26/2019  12:25 AM    <DIR>          images
#                1 File(s)        608,347 bytes
#                4 Dir(s)  12,494,794,752 bytes free

# %%
image = mpimg.imread("images/waymo.jpg")
print("Image dimensions: ", image.shape)
# Out:
# Image dimensions:  (1800, 2400, 3)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
gray_image.shape
# Out:
# (1800, 2400)

# %%
plt.figure(figsize=(12,12))
plt.imshow(gray_image, cmap='gray')

# %%
x = 190
y = 375
pixel_value = gray_image[y, x]

# %%
print(pixel_value)
# Out:
# 189
