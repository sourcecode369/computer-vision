# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
ls "images/"
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 1404-441A
#
#  Directory of C:\Users\User\Desktop\deep learning nanodegree\Computer_Vision\Image Representation\images
#
# 08/26/2019  12:43 AM    <DIR>          .
# 08/26/2019  12:43 AM    <DIR>          ..
# 08/26/2019  12:43 AM             7,279 pzza_image.jpg
# 08/25/2019  11:36 PM           866,686 waymo.jpg
#                2 File(s)        873,965 bytes
#                2 Dir(s)  11,418,152,960 bytes free

# %%
img = Image.open("images/pzza_image.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x4085617A58>

# %%
image = cv2.imread("images/pzza_image.jpg")

# %%
image.shape
# Out:
# (360, 480, 3)

# %%
image_copy = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_copy)

# %% [markdown]
# ### Define a color threshold

# %%
lower_blue = np.array([0,0,0])
upper_blue = np.array([50,50,212])

# %% [markdown]
# ### Create a mask

# %%
mask = cv2.inRange(image_copy,lower_blue,upper_blue)

# %%
plt.imshow(mask,cmap="gray")

# %%
masked_image = np.copy(image_copy)

# %%
masked_image[mask!=0] = [0,0,0]

# %%
plt.imshow(masked_image)
