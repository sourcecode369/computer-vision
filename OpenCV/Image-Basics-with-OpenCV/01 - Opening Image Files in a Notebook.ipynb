# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('../DATA/00-puppy.jpg')

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img_gray = cv2.imread('../DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
img_gray.min()
# Out:
# 1

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(img_gray,cmap="gray")

# %%
resized_img = cv2.resize(img, (1000,400))

# %%
plt.imshow(resized_img)

# %%
w_ratio = 0.2
h_ratio = 0.2

new_img = cv2.resize(img,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img = cv2.flip(img,0)

# %%
plt.imshow(new_img)

# %%
cv2.imwrite("totally_new.jpg",img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(new_img)
